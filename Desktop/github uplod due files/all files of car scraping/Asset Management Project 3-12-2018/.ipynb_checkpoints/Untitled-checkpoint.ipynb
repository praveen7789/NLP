# %%
import pandas as pd
import numpy as np

# %%
companies_table = pd.read_csv('./companies.csv')
companies_table
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
companies_table.permalink.nunique() # nunique is used to find the length of unique values
# Out:
# 66368

# %%
round_table=pd.read_csv('./rounds2.csv',encoding = "ISO-8859-1")
round_table
# Out:
#                                         company_permalink  \
# 0                                     /organization/-fame
# 1                                  /ORGANIZATION/-QOUNTER
# 2                                  /organization/-qounter
# 3                     /ORGANIZATION/-THE-ONE-OF-THEM-INC-
# 4                                   /organization/0-6-com
# 5                          /ORGANIZATION/004-TECHNOLOGIES
# 6                        /organization/01games-technology
# 7                     /ORGANIZATION/0NDINE-BIOMEDICAL-INC
# 8                     /organization/0ndine-biomedical-inc
# 9                                    /ORGANIZATION/0XDATA
# 10                                   /organization/0xdata
# 11                                   /ORGANIZATION/0XDATA
# 12                                   /organization/0xdata
# 13                                        /ORGANIZATION/1
# 14                                        /organization/1
# ...

# %%
round_table.company_permalink.nunique()
# Out:
# 90247

# %%
companies_name=companies_table['permalink'] # assigned permalink coloumn to companies_name

# %%
#import re
## list=round_table['company_permalink']
#y=round_table["company_permalink"]
#x=[]
#new = y.str.split("/", n = 1, expand = True) 
#for i in new[1]:
 #   x.append(i)
#x

# %%
companie1=[] 
for i in range(len(companies_name)):
    companie1.append(companies_name[i].split(sep='/')[2]) # splited the company name and extracted the company names
len(companie1) # this is in list formate
# Out:
# 66368

# %%
companies_table['companies']=companie1 # added the list to DataFrame table coloumns
companies_table
# Out:
#                                                permalink  \
# 0                                    /organization/-fame
# 1                                 /organization/-qounter
# 2                    /organization/-the-one-of-them-inc-
# 3                                  /organization/0-6-com
# 4                         /organization/004-technologies
# 5                       /organization/01games-technology
# 6                    /organization/0ndine-biomedical-inc
# 7                                   /organization/0xdata
# 8                                        /organization/1
# 9                              /organization/1-2-3-listo
# 10                                 /organization/1-4-all
# 11                        /organization/1-618-technology
# 12                           /organization/1-800-dentist
# 13                           /organization/1-800-doctors
# 14              /organization/1-800-publicrelations-inc-
# ...

# %%
companie1_r=[x.lower() for x in companies_table.companies] # converted the coloumn strings into lower case
#companies_table.companies.nunique()

# %% [markdown]
# # unique companies in companies_table = 66368

# %%
companies1=pd.Series(companie1_r) 
companies1=companies1.unique()
#companies1.nunique() # number of unique values in companynames
len(companies1)
#type(companies1)
# Out:
# 66368

# %% [markdown]
# # round2 table starts

# %%
round2_names=round_table['company_permalink'] # assigned the coloumn to new varible

# %%
companie2=[] 
for i in range(len(round2_names)):
    companie2.append(round2_names[i].split(sep='/')[2]) # splited each string in coloumn by '/' and assgned 2nd value to new list
len(companie2)
# Out:
# 114949

# %%
companies2=[x.lower() for x in companie2] # converted the list values to lowercase
# Out:
# ['-fame',
#  '-qounter',
#  '-qounter',
#  '-the-one-of-them-inc-',
#  '0-6-com',
#  '004-technologies',
#  '01games-technology',
#  '0ndine-biomedical-inc',
#  '0ndine-biomedical-inc',
#  '0xdata']

# %% [markdown]
# # unique companies in round2 = 66370

# %%
companies2=pd.Series(companies2)
companies2=companies2.unique()
len(companies2)
#companies2.nunique() # number of unique values in coloumn
# Out:
# 66370

# %% [markdown]
# # unique organisations in round2 table = 90247

# %%
companies_table.describe()
# Out:
#        funding_rounds
# count    66368.000000
# mean         1.732522
# std          1.360251
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000

# %%
companies_table.name.nunique() # nunique is used to find the length of unique values
# Out:
# 66102

# %% [markdown]
# # unique coloumn is "funding_rounds" = 66102

# %%
companies_table.isnull().sum() # gives the count of null values in each coloumn
# Out:
# permalink                0
# name                     1
# homepage_url          5058
# category_list         3148
# funding_total_usd        0
# status                   0
# country_code          6958
# state_code            8547
# region                8030
# city                  8028
# funding_rounds           0
# founded_at           15221
# first_funding_at        24
# last_funding_at          0
# companies                0
# dtype: int64

# %%
print(p ,'\n', q)
# Out:
# ['-fame', '-qounter', '-the-one-of-them-inc-', '0-6-com', '004-technologies', '01games-technology', '0ndine-biomedical-inc', '0xdata', '1', '1-2-3-listo']
#  ['-fame', '-qounter', '-qounter', '-the-one-of-them-inc-', '0-6-com', '004-technologies', '01games-technology', '0ndine-biomedical-inc', '0ndine-biomedical-inc', '0xdata']

# %% [markdown]
# # coding for common strins i two lists

# %%
# comparing two lists varibles wether the element in one list is there in other list or not
q=companies2[:10] 
p=companie1_r[:10]


xx=[]
for j in range(len(q)):
    for i in range(len(p)):
        if p[i] == q[j]:
            xx.append(i)
print(xx)
# Out:
# [0, 1, 1, 2, 3, 4, 5, 6, 6, 7]

# %%
# finally checked the string which is there in both the lists 
# common string in both list
xx=[]
for j in range(len(q)):
    for i in p:
        if i == q[j]:
            xx.append(i)
yy=pd.Series(xx)  
yy.unique()
# Out:
# array(['-fame', '-qounter', '-the-one-of-them-inc-', '0-6-com',
#        '004-technologies', '01games-technology', '0ndine-biomedical-inc',
#        '0xdata'], dtype=object)

# %% [markdown]
# # number of common companies in both tables = 66300

# %%
common=[]
for j in range(len(companies2)):
    for i in companie1_r:
        if i == companies2[j]:
            common.append(i)
common
# Out:
# ['-fame',
#  '-qounter',
#  '-qounter',
#  '-the-one-of-them-inc-',
#  '0-6-com',
#  '004-technologies',
#  '01games-technology',
#  '0ndine-biomedical-inc',
#  '0ndine-biomedical-inc',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '0xdata',
#  '1',
#  '1',
#  '1',
#  '1-2-3-listo',
#  '1-4-all',
#  '1-618-technology',
#  '1-800-dentist',
#  '1-800-doctors',
#  '1-800-publicrelations-inc-',
#  '1-mainstream',
#  '1-of-99',
#  '10-20-media',
#  '10-20-media',
#  '10-20-media',
#  '10-20-media',
#  '10-minutes-with',
#  '10-minutes-with',
#  '1000-corks',
#  '1000-markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000memories',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1000museums-com',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001-menus',
#  '1001pharmacies-com',
#  '1006-tv',
#  '1006-tv',
#  '1006-tv',
# ...

# %%
uni=pd.Series(common)
uni.nunique()
# Out:
# 66300

# %%
companies1=list(companies1)
companies2=list(companies2)
print(type(companies1) ,'\t',type(companies2))
# Out:
# <class 'list'> 	 <class 'list'>

# %% [markdown]
# # number of common companies in both tables = 66300
# - this is compared between unique companys list

# %%
common2=[]
for j in range(len(companies2)):
    for i in companies1:
        if i == companies2[j]:
            common2.append(i)
common2
# Out:
# ['-fame',
#  '-qounter',
#  '-the-one-of-them-inc-',
#  '0-6-com',
#  '004-technologies',
#  '01games-technology',
#  '0ndine-biomedical-inc',
#  '0xdata',
#  '1',
#  '1-2-3-listo',
#  '1-4-all',
#  '1-618-technology',
#  '1-800-dentist',
#  '1-800-doctors',
#  '1-800-publicrelations-inc-',
#  '1-mainstream',
#  '1-of-99',
#  '10-20-media',
#  '10-minutes-with',
#  '1000-corks',
#  '1000-markets',
#  '1000chi',
#  '1000lookz',
#  '1000memories',
#  '1000museums-com',
#  '1001-menus',
#  '1001pharmacies-com',
#  '1006-tv',
#  '100du-tv',
#  '100e-com',
#  '100health',
#  '100plus',
#  '1010data',
#  '10alike',
#  '10bestthings',
#  '10k-2',
#  '10sec',
#  '10seconds-software',
#  '10six',
#  '10tracks-2',
#  '10x-genomics',
#  '10x-technologies',
#  '10x10-room',
#  '11-health',
#  '115-network-disks',
#  '117go',
#  '11i-solutions',
#  '12-labs',
#  '12-star-survival',
#  '120-sports',
#  '121-rentals',
#  '121cast',
#  '121nexus',
#  '1234enter',
#  '123contactform',
# ...

# %%
len(common2)
# Out:
# 66300
