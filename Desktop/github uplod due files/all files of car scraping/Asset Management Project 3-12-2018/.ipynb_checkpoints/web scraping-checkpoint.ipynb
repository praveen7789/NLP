# %%
import urllib.request

# %%
html='https://www.worldatlas.com/aatlas/ctycodes.htm'

# %%
html_doc=urllib.request.urlopen(html)

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(html_doc, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <title>
#    2-Letter, 3-Letter, Country Codes for All Countries in the World
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="2-letter country codes, 3-letter country codes and a world atlas of facts flags and maps including every continent, country, dependency, exotic destination, island, major city, ocean, province, state &amp; territory on the planet!" name="description"/>
#   <meta content="1534891833401557" property="fb:app_id"/>
#   <meta content="518129666" property="fb:admins"/>
#   <meta content="100004698243421" property="fb:admins"/>
#   <meta content="150031197968" property="fb:pages"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="78AC2666D9EAA4D74DAFB87B3172164D" name="msvalidate.01">
#    <link href="https://www.worldatlas.com/aatlas/ctycodes.htm" rel="canonical"/>
#    <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.3/jquery.min.js">
#    </script>
# ...

# %%
table=soup.find('table')

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]

for row in table.find_all("tr"):
    cells = row.find_all('td')
  
    if len(cells)==5: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))

# %%
#import pandas to convert list to data frame
import pandas as pd
A.pop(0)
B.pop(0)
C.pop(0)
D.pop(0)
E.pop(0)
df=pd.DataFrame(A,columns=['Country'])
df['A2(ISO)']=B
df['A3(UN)']=C
df['NUM(UN)']=D
df['Dial(cod)']=E

df
# Out:
#                                   Country A2(ISO) A3(UN) NUM(UN) Dial(cod)
# 0                             Afghanistan      AF    AFG       4        93
# 1                                 Albania      AL    ALB       8       355
# 2                                 Algeria      DZ    DZA      12       213
# 3                          American Samoa      AS    ASM      16     1-684
# 4                                 Andorra      AD    AND      20       376
# 5                                  Angola      AO    AGO      24       244
# 6                                Anguilla      AI    AIA     660     1-264
# 7                              Antarctica      AQ    ATA      10       672
# 8                     Antigua and Barbuda      AG    ATG      28     1-268
# 9                               Argentina      AR    ARG      32        54
# 10                                Armenia      AM    ARM      51       374
# ...

# %%
country=df.Country
di_3=df['A3(UN)']

# %%
di_3[:12]
# Out:
# 0     AFG
# 1     ALB
# 2     DZA
# 3     ASM
# 4     AND
# 5     AGO
# 6     AIA
# 7     ATA
# 8     ATG
# 9     ARG
# 10    ARM
# 11    ABW
# Name: A3(UN), dtype: object

# %%
html1='https://opinionfront.com/complete-list-of-english-speaking-countries'

# %%
html1_doc=urllib.request.urlopen(html1)

# %%
from bs4 import BeautifulSoup

# %%
soup1=BeautifulSoup(html1_doc, 'html.parser')

# %%
table2=soup1.find('table', class_=" ct-table ct-table-bordered")

# %%
tr=table2.find_all('tr')
tr[4]
# Out:
# <tr>
# <td>#4</td>
# <td>British Indian Ocean Territory</td>
# <td>3,000</td>
# <td>3,000</td>
# <td>100</td>
# </tr>

# %%
w=[]
for i in range(len(tr)):
    w.append(tr[i].text.split(sep='\n')[2])
w
# Out:
# ['COUNTRY/TERRITORY',
#  'Isle of Man',
#  'American Samoa',
#  'Gibraltar',
#  'British Indian Ocean Territory',
#  'Barbados',
#  'United Kingdom',
#  'Ireland',
#  'New Zealand',
#  'Jamaica',
#  'Australia',
#  'Bermuda',
#  'U.S. Virgin Islands',
#  'Falkland Islands',
#  'St. Vincent and the Grenadines',
#  'United States',
#  'Dominica',
#  'Niue',
#  'Marshall Islands',
#  'Palau',
#  'Anguilla',
#  'Pitcairn Islands',
#  'Guam',
#  'Grenada',
#  'Guyana',
#  'Netherlands',
#  'Malta',
#  'Trinidad and Tobago',
#  'Bahamas',
#  'Suriname',
#  'British Virgin Islands',
#  'Sweden',
#  'Denmark',
#  'Canada',
#  'Israel',
#  'Vanuatu',
#  'Sierra Leone',
#  'Northern Mariana Islands',
#  'Liberia',
#  'St. Helena',
#  'Belize',
#  'Singapore',
#  'Antigua and Barbuda',
#  'Norfolk Island',
#  'St. Kitts and Nevis',
#  'Cayman Islands',
#  'Austria',
#  'Cyprus',
#  'Finland',
#  'Montserrat',
#  'Germany',
#  'Switzerland',
#  'Nauru',
#  'Belgium',
#  'Slovenia',
# ...

# %%
companie1=[] 
for i in range(len(companies_name)):
    companie1.append(companies_name[i].split(sep='/')[2]) # splited the company name and extracted the company names
len(companie1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-68cd19f4a0a2> in <module>()
#       1 companie1=[]
# ----> 2 for i in range(len(companies_name)):
#       3     companie1.append(companies_name[i].split(sep='/')[2]) # splited the company name and extracted the company names
#       4 len(companie1)
#
# NameError: name 'companies_name' is not defined

# %%
#Generate lists
x=[]
y=[]
z=[]
a=[]
b=[]
for row in table2.find_all("tr"):
    cells = row.find_all('td')
  
    if len(cells)==3: #Only extract table body not heading
        x.append(cells[0].find(text=True))
        y.append(cells[1].find(text=True))
        z.append(cells[2].find(text=True))
        a.append(cells[3].find(text=True))
        b.append(cells[4].find(text=True))

# %%
x
# Out:
# []

# %%
df1=pd.DataFrame(x,columns=['Country'])
df1['region']=y
df1['population']=z

df1
# Out:
# Empty DataFrame
# Columns: [Country, region, population]
# Index: []

# %%
tr=soup.find_all('tr')
len(tr)

# %%
# another code
P=[]
for i in tr:
    P.append(i.text)
P[2]

# %%
#Generate lists
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
G=[]
for row in right_table.findAll("tr"):
    cells = row.findAll('td')
    states=row.findAll('th') #To store second column data
    if len(cells)==6: #Only extract table body not heading
        A.append(cells[0].find(text=True))
        B.append(states[0].find(text=True))
        C.append(cells[1].find(text=True))
        D.append(cells[2].find(text=True))
        E.append(cells[3].find(text=True))
        F.append(cells[4].find(text=True))
        G.append(cells[5].find(text=True))
