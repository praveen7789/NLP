# %% [raw]
# text process
#  - remove special characters
#  - lower or upper
#  - lemma
#  - stemming
# - TFIDF , Count vectorizer== Bag of words

# %% [raw]
# Dimension Reduction  = hashing Trick 'or' PCA
# - apply cosine similarity  (select top 10)
# - 2nd model navi base
# models(ML,cosine,distance,DL,RNN)

# %%
import pandas as pd
import numpy as np
import nltk 
from nltk.stem import wordnet
from nltk import pos_tag

# %%
text = pd.read_csv('./spam.csv',encoding='latin-1')
text
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# 5     spam  FreeMsg Hey there darling it's been 3 week's n...        NaN
# 6      ham  Even my brother is not like to speak with me. ...        NaN
# 7      ham  As per your request 'Melle Melle (Oru Minnamin...        NaN
# 8     spam  WINNER!! As a valued network customer you have...        NaN
# 9     spam  Had your mobile 11 months or more? U R entitle...        NaN
# 10     ham  I'm gonna be home soon and i don't want to tal...        NaN
# 11    spam  SIX chances to win CASH! From 100 to 20,000 po...        NaN
# ...

# %%
newv1 = []
for i in  text['v1']:
    if i == 'ham':
        newv1.append(0)
    else:
        newv1.append(1)

# %%
text['newv1'] = newv1

# %%
text.drop(columns=['v1','Unnamed: 2','Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %% [markdown]
# # text preprosesing

# %%
import re
def textprocess(data):
    data = data.lower() # converting in to lower case
    data = re.sub(r'[^a-z0-9]+',' ',data)
    return data

# %%
text['v2'] = text['v2'].apply(textprocess)

# %%
text
# Out:
#                                                      v2  newv1
# 0     go until jurong point crazy available only in ...      0
# 1                              ok lar joking wif u oni       0
# 2     free entry in 2 a wkly comp to win fa cup fina...      1
# 3          u dun say so early hor u c already then say       0
# 4     nah i don t think he goes to usf he lives arou...      0
# 5     freemsg hey there darling it s been 3 week s n...      1
# 6     even my brother is not like to speak with me t...      0
# 7     as per your request melle melle oru minnaminun...      0
# 8     winner as a valued network customer you have b...      1
# 9     had your mobile 11 months or more u r entitled...      1
# 10    i m gonna be home soon and i don t want to tal...      0
# 11    six chances to win cash from 100 to 20 000 pou...      1
# 12    urgent you have won a 1 week free membership i...      1
# 13    i ve been searching for the right words to tha...      0
# ...

# %% [markdown]
# # lemma

# %%
lema = wordnet.WordNetLemmatizer()

# %%
def lemmatizer(pos_tag):
    word,pos=pos_tag
    if pos.startswith('R'):
        pos = 'r'
    elif pos.startswith('V'):
        pos = 'v'
    elif pos.startswith('J'):
        pos ='a'
    else:
        pos='n'
    return lema.lemmatize(word,pos=pos)

# %%
def joinlema(sent):
    tokens = sent.split() # spliting the sentence in to words 
    pos = pos_tag(tokens) # taging parts of speatch 
    return " ".join([lemmatizer(tag) for tag in pos])

# %%
text['lema'] = text['v2'].apply(joinlema)

# %%
text.head()
# Out:
#                                                   v2  newv1  \
# 0  go until jurong point crazy available only in ...      0
# 1                           ok lar joking wif u oni       0
# 2  free entry in 2 a wkly comp to win fa cup fina...      1
# 3       u dun say so early hor u c already then say       0
# 4  nah i don t think he goes to usf he lives arou...      0
#
#                                                 lema
# 0  go until jurong point crazy available only in ...
# 1                            ok lar joking wif u oni
# 2  free entry in 2 a wkly comp to win fa cup fina...
# 3        u dun say so early hor u c already then say
# 4  nah i don t think he go to usf he live around ...

# %% [markdown]
# # TF-IDF
# $tfidf = log(TF+1) * log(\frac{N}{DF+1})$
#  - TF = Term Frequency
#  - DF = Document Frequency
#  - N = Number of times word is repeated in entire corpus
# - term=word
# ### +1 is added because the value should not be == infinite

# %% [markdown]
# # Insted of rempoving stopwords we apply TFIDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer()

# %%
X = tfidf.fit_transform(text['lema']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity
